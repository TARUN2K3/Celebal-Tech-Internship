# %% [markdown]
# <a href="https://colab.research.google.com/github/TARUN2K3/Celebal-Tech-Internship/blob/master/Assignment_3_Celebal_Internship_Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# Map species to their names
species_map = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
iris_df['species'] = iris_df['species'].map(species_map)

# Pair plot
sns.pairplot(iris_df, hue='species', markers=["o", "s", "D"])
plt.show()

# %%
# Box plot
plt.figure(figsize=(10, 7))
sns.boxplot(x='species', y='sepal length (cm)', data=iris_df)
plt.title('Box Plot of Sepal Length by Species')
plt.show()

plt.figure(figsize=(10, 7))
sns.boxplot(x='species', y='sepal width (cm)', data=iris_df)
plt.title('Box Plot of Sepal Width by Species')
plt.show()

# %%
# Violin plot
plt.figure(figsize=(10, 7))
sns.violinplot(x='species', y='petal length (cm)', data=iris_df)
plt.title('Violin Plot of Petal Length by Species')
plt.show()

plt.figure(figsize=(10, 7))
sns.violinplot(x='species', y='petal width (cm)', data=iris_df)
plt.title('Violin Plot of Petal Width by Species')
plt.show()

# %%
# Correlation matrix heatmap
plt.figure(figsize=(10, 7))
corr = iris_df.iloc[:, :-1].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of Feature Correlations')
plt.show()
